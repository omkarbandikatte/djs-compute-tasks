# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\omkar\OneDrive\Desktop\DJS_COMPUTE\data (1).csv")
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05
# 2           J. Oblak                            Jan Oblak   27  1993-01-07
# 3     R. Lewandowski                   Robert Lewandowski   31  1988-08-21
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28  1992-02-05
#
#    height_cm  weight_kg nationality            club_name  ...   lwb   ldm  \
# ...

# %%
data.shape
# Out:
# (18944, 106)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Columns: 106 entries, sofifa_id to rb
# dtypes: float64(18), int64(44), object(44)
# memory usage: 15.3+ MB

# %%
data.drop(['sofifa_id','player_url'],axis=1,inplace=True)
data
# Out:
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35
# 2               J. Oblak                            Jan Oblak   27
# 3         R. Lewandowski                   Robert Lewandowski   31
# 4              Neymar Jr        Neymar da Silva Santos Júnior   28
# ...                  ...                                  ...  ...
# 18939          K. Angulo                         Kevin Angulo   24
# 18940     Zhang Mengxuan                       Mengxuan Zhang   21
# 18941      Wang Zhenghao                                  王政豪   20
# 18942        Chen Zitong                          Zitong Chen   23
# 18943           Song Yue                             Yue Song   28
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# ...

# %%
data.iloc[:,:60].isnull().sum()
# Out:
# short_name                        0
# long_name                         0
# age                               0
# dob                               0
# height_cm                         0
# weight_kg                         0
# nationality                       0
# club_name                       225
# league_name                     225
# league_rank                     225
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# player_positions                  0
# preferred_foot                    0
# international_reputation          0
# weak_foot                         0
# skill_moves                       0
# work_rate                         0
# body_type                         0
# real_face                         0
# release_clause_eur              995
# player_tags                   17536
# team_position                   225
# team_jersey_number              225
# ...

# %%
data.iloc[:,59:107].isnull().sum()
# Out:
# power_shot_power                 0
# power_jumping                    0
# power_stamina                    0
# power_strength                   0
# power_long_shots                 0
# mentality_aggression             0
# mentality_interceptions          0
# mentality_positioning            0
# mentality_vision                 0
# mentality_penalties              0
# mentality_composure              0
# defending_marking            18944
# defending_standing_tackle        0
# defending_sliding_tackle         0
# goalkeeping_diving               0
# goalkeeping_handling             0
# goalkeeping_kicking              0
# goalkeeping_positioning          0
# goalkeeping_reflexes             0
# ls                               0
# st                               0
# rs                               0
# lw                               0
# lf                               0
# cf                               0
# rf                               0
# rw                               0
# ...

# %% [markdown]
# # Deleting the Columns
# - player_tags
# - loaned_from
# - nation_position
# - nation_jersey_number
# - gk_diving
# - gk_handling
# - gk_kicking
# - gk_reflexes
# - gk_speed
# - gk_positioning
# - defending_marking

# %%
data.drop(['player_tags','loaned_from','nation_position','nation_jersey_number','gk_diving','gk_handling','gk_kicking','gk_reflexes','gk_speed','gk_positioning','defending_marking','player_traits'],axis=1,inplace=True)
data
# Out:
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35
# 2               J. Oblak                            Jan Oblak   27
# 3         R. Lewandowski                   Robert Lewandowski   31
# 4              Neymar Jr        Neymar da Silva Santos Júnior   28
# ...                  ...                                  ...  ...
# 18939          K. Angulo                         Kevin Angulo   24
# 18940     Zhang Mengxuan                       Mengxuan Zhang   21
# 18941      Wang Zhenghao                                  王政豪   20
# 18942        Chen Zitong                          Zitong Chen   23
# 18943           Song Yue                             Yue Song   28
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Data columns (total 92 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   short_name                  18944 non-null  object
#  1   long_name                   18944 non-null  object
#  2   age                         18944 non-null  int64
#  3   dob                         18944 non-null  object
#  4   height_cm                   18944 non-null  int64
#  5   weight_kg                   18944 non-null  int64
#  6   nationality                 18944 non-null  object
#  7   club_name                   18719 non-null  object
#  8   league_name                 18719 non-null  object
#  9   league_rank                 18719 non-null  float64
#  10  overall                     18944 non-null  int64
#  11  potential                   18944 non-null  int64
#  12  value_eur                   18944 non-null  int64
# ...

# %%
data.iloc[:,:60].isnull().sum()
# Out:
# short_name                       0
# long_name                        0
# age                              0
# dob                              0
# height_cm                        0
# weight_kg                        0
# nationality                      0
# club_name                      225
# league_name                    225
# league_rank                    225
# overall                          0
# potential                        0
# value_eur                        0
# wage_eur                         0
# player_positions                 0
# preferred_foot                   0
# international_reputation         0
# weak_foot                        0
# skill_moves                      0
# work_rate                        0
# body_type                        0
# real_face                        0
# release_clause_eur             995
# team_position                  225
# team_jersey_number             225
# joined                         983
# contract_valid_until           225
# ...

# %%
data.iloc[:,59:94].isnull().sum()
# Out:
# defending_standing_tackle    0
# defending_sliding_tackle     0
# goalkeeping_diving           0
# goalkeeping_handling         0
# goalkeeping_kicking          0
# goalkeeping_positioning      0
# goalkeeping_reflexes         0
# ls                           0
# st                           0
# rs                           0
# lw                           0
# lf                           0
# cf                           0
# rf                           0
# rw                           0
# lam                          0
# cam                          0
# ram                          0
# lm                           0
# lcm                          0
# cm                           0
# rcm                          0
# rm                           0
# lwb                          0
# ldm                          0
# cdm                          0
# rdm                          0
# rwb                          0
# lb                           0
# lcb                          0
# ...

# %%
data.dropna(subset='club_name',inplace=True)
data.dropna(subset='pace',inplace=True)
data
# Out:
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35
# 3         R. Lewandowski                   Robert Lewandowski   31
# 4              Neymar Jr        Neymar da Silva Santos Júnior   28
# 5           K. De Bruyne                      Kevin De Bruyne   29
# ...                  ...                                  ...  ...
# 18939          K. Angulo                         Kevin Angulo   24
# 18940     Zhang Mengxuan                       Mengxuan Zhang   21
# 18941      Wang Zhenghao                                  王政豪   20
# 18942        Chen Zitong                          Zitong Chen   23
# 18943           Song Yue                             Yue Song   28
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# ...

# %% [markdown]
# # Counting the Players based on thier Height

# %%
plt.figure(figsize = (22, 8))
ax = sns.countplot(x = 'height_cm', data = data)
ax.set_title(label = 'Count of players on Basis of Height', fontsize = 20)
ax.set_xlabel(xlabel = 'Height in Foot per inch', fontsize = 16)
ax.set_ylabel(ylabel = 'Count', fontsize = 16)
plt.show()

# %% [markdown]
# # Height vs Dribbling

# %%
plt.figure(figsize = (22, 8))
sns.barplot(x='height_cm',y='dribbling',data=data.sort_values('height_cm',inplace=False))
plt.xlabel('Height in cm',fontsize=20)
plt.ylabel('Dribbling',fontsize=20)
plt.title('Height vs Dribbling')
plt.show()

# %% [markdown]
# # Weight vs Dribbling

# %%
plt.figure(figsize =  (22,5))
sns.barplot(x='weight_kg',y='dribbling',data=data.sort_values('weight_kg',inplace=False))
# Out:
# <Axes: xlabel='weight_kg', ylabel='dribbling'>

# %%
plt.figure(figsize = (22,8))
sns.barplot(x='height_cm',y='weight_kg',data=data.sort_values('height_cm',inplace=False))
plt.xlabel('height')
plt.ylabel('weight')
# Out:
# Text(0, 0.5, 'weight')

# %% [markdown]
# # Work Rate of the Players in FiFa 21

# %%
plt.figure(figsize = (15, 7))

sns.countplot(x = 'work_rate', data = data, palette = 'hls')
plt.title('Different work rates of the Players Participating in the FIFA 2021', fontsize = 20)
plt.xlabel('Work rates associated with the players', fontsize = 16)
plt.ylabel('count of Players', fontsize = 16)
plt.show()
